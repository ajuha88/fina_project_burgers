# %% [markdown]
# convert .csv to .sqlite

# %%
# Ignore SQLITE warnings related to Decimal numbers in the Chinook database
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import func
import pandas as pd

# %%
engine = create_engine('sqlite:///final_project_burgers/DATA/burger_joints.sqlite', echo=False)

# %%
# Reference to CSV and reading CSV into Pandas DataFrame
csv_path = "final_project_burgers/DATA/burger_joints.csv"
burger_df = pd.read_csv(csv_path, encoding="latin")

# burger_df.sort_values(by=['Venue Category']).unique
# a = burger_df['Venue Category'].unique()
# Out:
#    Unnamed: 0 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0           0   Co-op City              40.874294              -73.829939
# 1           1  Eastchester              40.887556              -73.827806
# 2           2  Kingsbridge              40.881687              -73.902818
# 3           3  Kingsbridge              40.881687              -73.902818
# 4           4  Kingsbridge              40.881687              -73.902818
#
#                    Venue ID                  Venue  Venue Latitude  \
# 0  4be2b79d660ec9284d04ca3b   Townhouse Restaurant       40.876086
# 1  4c406f2e6c1a9521a042b96a             McDonald's       40.885636
# 2  55568a71498e3524400a356e            Smashburger       40.884221
# 3  4b3789f3f964a520f34125e3        Riverdale Diner       40.885183
# 4  4b9c9c6af964a520b27236e3  Land & Sea Restaurant       40.877885
#
#    Venue Longitude      Venue Category  Count  Rating
# 0       -73.828868          Restaurant      5     5.8
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# engine = create_engine('sqlite:///path', echo=False)

burger_df = pd.read_csv("final_project_burgers/DATA/burger_joints.csv", encoding="latin")
burger_df.to_sql('burgers', con=engine, if_exists='append')

# %%
res = burger_df.nunique()\
        .sort_values(ascending=False)\
        .rename('Count')\
        .to_frame()
res
# Out:
#                         Count
# Unnamed: 0                226
# Venue Longitude           208
# Venue Latitude            208
# Venue ID                  208
# Venue                     180
# Count                     102
# Neighborhood Longitude     59
# Neighborhood Latitude      59
# Neighborhood               59
# Rating                     43
# Venue Category             35
